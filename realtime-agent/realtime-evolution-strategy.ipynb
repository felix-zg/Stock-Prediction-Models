# %%
from sklearn.preprocessing import MinMaxScaler
import os
import numpy as np
import pandas as pd
import time
import random

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
def softmax(z):
    assert len(z.shape) == 2
    s = np.max(z, axis=1)
    s = s[:, np.newaxis]
    e_x = np.exp(z - s)
    div = np.sum(e_x, axis=1)
    div = div[:, np.newaxis]
    return e_x / div

# %%
df = pd.read_csv('FB.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-05-23  182.500000  186.910004  182.179993  186.899994  186.899994
# 1  2018-05-24  185.880005  186.800003  185.029999  185.929993  185.929993
# 2  2018-05-25  186.020004  186.330002  184.449997  184.919998  184.919998
# 3  2018-05-29  184.339996  186.809998  183.710007  185.740005  185.740005
# 4  2018-05-30  186.539993  188.000000  185.250000  187.669998  187.669998
#
#      Volume
# 0  16628100
# 1  12354700
# 2  10965100
# 3  16398900
# 4  13736900

# %%
parameters = [df['Close'].tolist(), df['Volume'].tolist()]

# %%
def get_state(parameters, t, window_size = 20):
    outside = []
    d = t - window_size + 1
    for parameter in parameters:
        block = (
            parameter[d : t + 1]
            if d >= 0
            else -d * [parameter[0]] + parameter[0 : t + 1]
        )
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        for i in range(1, window_size, 1):
            res.append(block[i] - block[0])
        outside.append(res)
    return np.array(outside).reshape((1, -1))

# %% [markdown]
# Our output size from `get_state` is 38. In this notebook, I only use `Close` and `Volume` parameters, you can choose any parameters you want from your DataFrame.
#
# After that, I want to add another parameters, my `inventory` size, mean of `inventory` and `capital`.
#
# Let say for an example,
# ```
# inventory_size = 1
# mean_inventory = 0.5
# capital = 2
# last_state = 0
# ```
#
# We have 3 actions,
#
# 1. `0` for do nothing.
# 2. `1` for buy.
# 3. `2` for sell.

# %%
inventory_size = 1
mean_inventory = 0.5
capital = 2
concat_parameters = np.concatenate([get_state(parameters, 20), [[inventory_size, 
                                                                mean_inventory,
                                                                capital]]], axis = 1)

# %%
input_size = concat_parameters.shape[1]
input_size
# Out:
# 79

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights
    
    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')
        
class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.rand(input_size, layer_size)
            * np.sqrt(1 / (input_size + layer_size)),
            np.random.rand(layer_size, output_size)
            * np.sqrt(1 / (layer_size + output_size)),
            np.zeros((1, layer_size)),
            np.zeros((1, output_size)),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-2]
        decision = np.dot(feed, self.weights[1]) + self.weights[-1]
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, timeseries, skip, initial_money, real_trend, minmax):
        self.model = model
        self.timeseries = timeseries
        self.skip = skip
        self.real_trend = real_trend
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )
        self.minmax = minmax
        self._initiate()

    def _initiate(self):
        # i assume first index is the close value
        self.trend = self.timeseries[0]
        self._mean = np.mean(self.trend)
        self._std = np.std(self.trend)
        self._inventory = []
        self._capital = self.initial_money
        self._queue = []
        self._scaled_capital = self.minmax.transform([[self._capital, 2]])[0, 0]

    def reset_capital(self, capital):
        if capital:
            self._capital = capital
        self._scaled_capital = self.minmax.transform([[self._capital, 2]])[0, 0]
        self._queue = []
        self._inventory = []

    def trade(self, data):
        """
        you need to make sure the data is [close, volume]
        """
        scaled_data = self.minmax.transform([data])[0]
        real_close = data[0]
        close = scaled_data[0]
        if len(self._queue) >= window_size:
            self._queue.pop(0)
        self._queue.append(scaled_data)
        if len(self._queue) < window_size:
            return {
                'status': 'data not enough to trade',
                'action': 'fail',
                'balance': self._capital,
                'timestamp': str(datetime.now()),
            }
        state = self.get_state(
            window_size - 1,
            self._inventory,
            self._scaled_capital,
            timeseries = np.array(self._queue).T.tolist(),
        )
        action, prob = self.act_softmax(state)
        print(prob)
        if action == 1 and self._scaled_capital >= close:
            self._inventory.append(close)
            self._scaled_capital -= close
            self._capital -= real_close
            return {
                'status': 'buy 1 unit, cost %f' % (real_close),
                'action': 'buy',
                'balance': self._capital,
                'timestamp': str(datetime.now()),
            }
        elif action == 2 and len(self._inventory):
            bought_price = self._inventory.pop(0)
            self._scaled_capital += close
            self._capital += real_close
            scaled_bought_price = self.minmax.inverse_transform(
                [[bought_price, 2]]
            )[0, 0]
            try:
                invest = (
                    (real_close - scaled_bought_price) / scaled_bought_price
                ) * 100
            except:
                invest = 0
            return {
                'status': 'sell 1 unit, price %f' % (real_close),
                'investment': invest,
                'gain': real_close - scaled_bought_price,
                'balance': self._capital,
                'action': 'sell',
                'timestamp': str(datetime.now()),
            }
        else:
            return {
                'status': 'do nothing',
                'action': 'nothing',
                'balance': self._capital,
                'timestamp': str(datetime.now()),
            }

    def change_data(self, timeseries, skip, initial_money, real_trend, minmax):
        self.timeseries = timeseries
        self.skip = skip
        self.initial_money = initial_money
        self.real_trend = real_trend
        self.minmax = minmax
        self._initiate()

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))

        return np.argmax(decision[0])

    def act_softmax(self, sequence):
        decision = self.model.predict(np.array(sequence))

        return np.argmax(decision[0]), softmax(decision)[0]

    def get_state(self, t, inventory, capital, timeseries):
        state = get_state(timeseries, t)
        len_inventory = len(inventory)
        if len_inventory:
            mean_inventory = np.mean(inventory)
        else:
            mean_inventory = 0
        z_inventory = (mean_inventory - self._mean) / self._std
        z_capital = (capital - self._mean) / self._std
        concat_parameters = np.concatenate(
            [state, [[len_inventory, z_inventory, z_capital]]], axis = 1
        )
        return concat_parameters

    def get_reward(self, weights):
        initial_money = self._scaled_capital
        starting_money = initial_money
        invests = []
        self.model.weights = weights
        inventory = []
        state = self.get_state(0, inventory, starting_money, self.timeseries)

        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= self.trend[t]

            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]
                invest = ((self.trend[t] - bought_price) / bought_price) * 100
                invests.append(invest)

            state = self.get_state(
                t + 1, inventory, starting_money, self.timeseries
            )
        invests = np.mean(invests)
        if np.isnan(invests):
            invests = 0
        score = (starting_money - initial_money) / initial_money * 100
        return invests * 0.7 + score * 0.3

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self._scaled_capital
        starting_money = initial_money

        real_initial_money = self.initial_money
        real_starting_money = self.initial_money
        inventory = []
        real_inventory = []
        state = self.get_state(0, inventory, starting_money, self.timeseries)
        states_sell = []
        states_buy = []

        for t in range(0, len(self.trend) - 1, self.skip):
            action, prob = self.act_softmax(state)
            print(t, prob)

            if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - 1 - window_size):
                inventory.append(self.trend[t])
                real_inventory.append(self.real_trend[t])
                real_starting_money -= self.real_trend[t]
                starting_money -= self.trend[t]
                states_buy.append(t)
                print(
                    'day %d: buy 1 unit at price %f, total balance %f'
                    % (t, self.real_trend[t], real_starting_money)
                )

            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                real_bought_price = real_inventory.pop(0)
                starting_money += self.trend[t]
                real_starting_money += self.real_trend[t]
                states_sell.append(t)
                try:
                    invest = (
                        (self.real_trend[t] - real_bought_price)
                        / real_bought_price
                    ) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, self.real_trend[t], invest, real_starting_money)
                )
            state = self.get_state(
                t + 1, inventory, starting_money, self.timeseries
            )

        invest = (
            (real_starting_money - real_initial_money) / real_initial_money
        ) * 100
        total_gains = real_starting_money - real_initial_money
        return states_buy, states_sell, total_gains, invest

# %%
stocks = [i for i in os.listdir(os.getcwd()) if '.csv' in i and not 'TWTR' in i]
stocks
# Out:
# ['LYFT.csv',
#  'CPRT.csv',
#  'FSV.csv',
#  'AMD.csv',
#  'FB.csv',
#  'TSLA.csv',
#  'GWR.csv',
#  'GOOG.csv',
#  'LB.csv',
#  'SINA.csv',
#  'MTDR.csv']

# %% [markdown]
# I want to train on all stocks I downloaded except for Twitter. I want to use Twitter for testing.

# %%
skip = 1
layer_size = 500
output_size = 3
window_size = 20

# %%
model = Model(input_size = input_size, layer_size = layer_size, output_size = output_size)
agent = None

for no, stock in enumerate(stocks):
    print('training stock %s'%(stock))
    df = pd.read_csv(stock)
    real_trend = df['Close'].tolist()
    parameters = [df['Close'].tolist(), df['Volume'].tolist()]
    minmax = MinMaxScaler(feature_range = (100, 200)).fit(np.array(parameters).T)
    scaled_parameters = minmax.transform(np.array(parameters).T).T.tolist()
    initial_money = np.max(parameters[0]) * 2
    
    if no == 0:
        agent = Agent(model = model,
                      timeseries = scaled_parameters,
                      skip = skip,
                      initial_money = initial_money,
                      real_trend = real_trend,
                      minmax = minmax)
    else:
        agent.change_data(timeseries = scaled_parameters,
                          skip = skip,
                          initial_money = initial_money,
                          real_trend = real_trend,
                          minmax = minmax)
    
    agent.fit(iterations = 100, checkpoint = 10)
    print()
# Out:
# training stock LYFT.csv
# iter 10. reward: 13.154827
# iter 20. reward: 18.915482
# iter 30. reward: 18.915482
# iter 40. reward: 18.915482
# iter 50. reward: 18.915482
# iter 60. reward: 18.915482
# iter 70. reward: 18.915482
# iter 80. reward: 18.915482
# iter 90. reward: 18.915482
# iter 100. reward: 18.915482
# time taken to train: 5.369779825210571 seconds
#
# training stock CPRT.csv
# iter 10. reward: -18.687098
# iter 20. reward: -22.938655
# iter 30. reward: -19.656127
# iter 40. reward: -29.603100
# iter 50. reward: -19.972715
# iter 60. reward: -20.266582
# iter 70. reward: -22.713864
# iter 80. reward: -20.377143
# iter 90. reward: -20.503848
# iter 100. reward: -18.579401
# time taken to train: 24.55108404159546 seconds
#
# training stock FSV.csv
# iter 10. reward: 23.434667
# iter 20. reward: 25.247528
# iter 30. reward: 28.654874
# iter 40. reward: 29.483385
# iter 50. reward: 32.154922
# iter 60. reward: 34.315971
# iter 70. reward: 36.228897
# iter 80. reward: 38.739289
# iter 90. reward: 40.463764
# iter 100. reward: 40.463764
# time taken to train: 23.560316801071167 seconds
#
# training stock AMD.csv
# iter 10. reward: 36.124079
# iter 20. reward: 38.113880
# iter 30. reward: 38.934663
# iter 40. reward: 40.096122
# iter 50. reward: 38.684720
# iter 60. reward: 41.621935
# iter 70. reward: 41.445677
# iter 80. reward: 42.171590
# iter 90. reward: 45.186825
# iter 100. reward: 56.591945
# time taken to train: 24.473583221435547 seconds
#
# training stock FB.csv
# iter 10. reward: -16.331169
# iter 20. reward: -15.249024
# iter 30. reward: -15.249024
# iter 40. reward: -15.249024
# iter 50. reward: -14.780495
# iter 60. reward: 7.062832
# iter 70. reward: 11.121210
# iter 80. reward: 11.340498
# iter 90. reward: 11.340498
# iter 100. reward: 15.651735
# time taken to train: 24.995929718017578 seconds
#
# training stock TSLA.csv
# iter 10. reward: -0.011192
# iter 20. reward: 3.095803
# iter 30. reward: 3.411257
# iter 40. reward: 3.411257
# iter 50. reward: 3.799184
# iter 60. reward: 4.267074
# iter 70. reward: 8.844461
# iter 80. reward: 12.208441
# iter 90. reward: 12.876170
# iter 100. reward: 13.722264
# time taken to train: 27.400449991226196 seconds
#
# training stock GWR.csv
# iter 10. reward: 15.503707
# iter 20. reward: 19.070286
# iter 30. reward: 22.652667
# iter 40. reward: 29.864144
# iter 50. reward: 30.518289
# iter 60. reward: 34.310622
# iter 70. reward: 34.060028
# iter 80. reward: 34.603357
# iter 90. reward: 33.137813
# iter 100. reward: 33.137813
# time taken to train: 26.63642907142639 seconds
#
# training stock GOOG.csv
# iter 10. reward: 14.388020
# iter 20. reward: 16.072361
# iter 30. reward: 17.714476
# iter 40. reward: 19.299807
# iter 50. reward: 17.166226
# iter 60. reward: 20.550868
# iter 70. reward: 22.439525
# iter 80. reward: 23.340313
# iter 90. reward: 23.458396
# iter 100. reward: 23.458396
# time taken to train: 29.526991844177246 seconds
#
# training stock LB.csv
# iter 10. reward: -8.639146
# iter 20. reward: -7.485294
# iter 30. reward: -2.064583
# iter 40. reward: -1.751481
# iter 50. reward: 1.232941
# iter 60. reward: 5.444483
# iter 70. reward: 5.768850
# iter 80. reward: 3.177628
# iter 90. reward: 12.097389
# iter 100. reward: 11.409051
# time taken to train: 28.159600973129272 seconds
#
# training stock SINA.csv
# iter 10. reward: -4.832076
# iter 20. reward: -0.521886
# iter 30. reward: 0.614410
# iter 40. reward: 0.862881
# iter 50. reward: 1.673954
# iter 60. reward: 4.474249
# iter 70. reward: 4.339732
# iter 80. reward: 5.127086
# iter 90. reward: 4.493398
# iter 100. reward: 4.616006
# time taken to train: 25.78930115699768 seconds
#
# training stock MTDR.csv
# iter 10. reward: 6.688359
# iter 20. reward: 10.744090
# iter 30. reward: 10.964188
# iter 40. reward: 10.643844
# iter 50. reward: 11.088678
# iter 60. reward: 11.946508
# iter 70. reward: 12.315052
# iter 80. reward: 12.752282
# iter 90. reward: 14.077039
# iter 100. reward: 15.381341
# time taken to train: 26.74873375892639 seconds
# /Users/felixweizmann/Documents/GitHub/Stock-Prediction-Models/venv/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/felixweizmann/Documents/GitHub/Stock-Prediction-Models/venv/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ### If you saw the whole training session on certain stocks are negatives (like FB), means that, that stock markets are losing very bad

# %%
df = pd.read_csv('GOOG.csv')
real_trend = df['Close'].tolist()
parameters = [df['Close'].tolist(), df['Volume'].tolist()]
minmax = MinMaxScaler(feature_range = (100, 200)).fit(np.array(parameters).T)
scaled_parameters = minmax.transform(np.array(parameters).T).T.tolist()
initial_money = np.max(parameters[0]) * 2

    
agent.change_data(timeseries = scaled_parameters,
                  skip = skip,
                  initial_money = initial_money,
                  real_trend = real_trend,
                  minmax = minmax)

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# 0 [0. 0. 1.]
# 1 [0. 0. 1.]
# 2 [0. 0. 1.]
# 3 [0. 0. 1.]
# 4 [0. 0. 1.]
# 5 [0. 0. 1.]
# 6 [0. 0. 1.]
# 7 [0. 0. 1.]
# 8 [2.56864693e-242 0.00000000e+000 1.00000000e+000]
# 9 [0. 0. 1.]
# 10 [0. 0. 1.]
# 11 [0. 0. 1.]
# 12 [0. 0. 1.]
# 13 [1. 0. 0.]
# 14 [0. 0. 1.]
# 15 [0. 0. 1.]
# 16 [0. 0. 1.]
# 17 [0. 1. 0.]
# day 17: buy 1 unit at price 1173.459961, total balance 1401.699951
# 18 [0. 0. 1.]
# day 18, sell 1 unit at price 1168.060059, investment -0.460169 %, total balance 2569.760010,
# 19 [0. 0. 1.]
# 20 [0. 0. 1.]
# 21 [0. 0. 1.]
# 22 [0. 0. 1.]
# 23 [0. 0. 1.]
# 24 [1. 0. 0.]
# 25 [1.00000000e+00 2.87639204e-82 0.00000000e+00]
# 26 [0. 1. 0.]
# day 26: buy 1 unit at price 1115.650024, total balance 1454.109986
# 27 [0. 1. 0.]
# day 27: buy 1 unit at price 1127.459961, total balance 326.650025
# 28 [0. 1. 0.]
# day 28: buy 1 unit at price 1102.890015, total balance -776.239990
# 29 [0. 1. 0.]
# day 29: buy 1 unit at price 1124.270020, total balance -1900.510010
# 30 [1. 0. 0.]
# 31 [0. 0. 1.]
# day 31, sell 1 unit at price 1154.050049, investment 3.441942 %, total balance -746.459961,
# 32 [1. 0. 0.]
# 33 [0. 0. 1.]
# day 33, sell 1 unit at price 1153.900024, investment 2.345100 %, total balance 407.440063,
# 34 [1. 0. 0.]
# 35 [1. 0. 0.]
# 36 [1. 0. 0.]
# 37 [1. 0. 0.]
# 38 [0. 1. 0.]
# day 38: buy 1 unit at price 1195.880005, total balance -788.439942
# 39 [0. 0. 1.]
# day 39, sell 1 unit at price 1186.959961, investment 7.622695 %, total balance 398.520019,
# 40 [1.00000000e+000 8.72432645e-225 0.00000000e+000]
# 41 [0. 1. 0.]
# day 41: buy 1 unit at price 1205.500000, total balance -806.979981
# 42 [0. 1. 0.]
# 43 [0. 1. 0.]
# 44 [0.00000000e+00 1.00000000e+00 1.49534712e-27]
# 45 [0. 1. 0.]
# 46 [0. 0. 1.]
# day 46, sell 1 unit at price 1219.739990, investment 8.491730 %, total balance 412.760009,
# 47 [0. 0. 1.]
# day 47, sell 1 unit at price 1217.260010, investment 1.787805 %, total balance 1630.020019,
# 48 [0. 0. 1.]
# day 48, sell 1 unit at price 1220.010010, investment 1.203651 %, total balance 2850.030029,
# 49 [0. 0. 1.]
# 50 [0. 0. 1.]
# 51 [0. 0. 1.]
# 52 [0. 0. 1.]
# 53 [0.00000000e+000 1.00000000e+000 2.03581213e-285]
# day 53: buy 1 unit at price 1245.609985, total balance 1604.420044
# 54 [0. 0. 1.]
# day 54, sell 1 unit at price 1249.099976, investment 0.280183 %, total balance 2853.520020,
# 55 [0. 0. 1.]
# 56 [0. 0. 1.]
# 57 [0. 0. 1.]
# 58 [0. 0. 1.]
# 59 [0. 0. 1.]
# 60 [1. 0. 0.]
# 61 [1. 0. 0.]
# 62 [1. 0. 0.]
# 63 [1. 0. 0.]
# 64 [0. 1. 0.]
# day 64: buy 1 unit at price 1205.380005, total balance 1648.140015
# 65 [1. 0. 0.]
# 66 [1. 0. 0.]
# 67 [1. 0. 0.]
# 68 [1. 0. 0.]
# 69 [0. 0. 1.]
# day 69, sell 1 unit at price 1239.119995, investment 2.799116 %, total balance 2887.260010,
# 70 [0. 0. 1.]
# 71 [0. 0. 1.]
# 72 [0. 0. 1.]
# 73 [0. 0. 1.]
# 74 [0. 0. 1.]
# 75 [0. 0. 1.]
# 76 [0. 1. 0.]
# day 76: buy 1 unit at price 1177.359985, total balance 1709.900025
# 77 [0. 1. 0.]
# day 77: buy 1 unit at price 1162.819946, total balance 547.080079
# 78 [0. 0. 1.]
# day 78, sell 1 unit at price 1175.329956, investment -0.172422 %, total balance 1722.410035,
# 79 [1. 0. 0.]
# 80 [0. 0. 1.]
# day 80, sell 1 unit at price 1156.050049, investment -0.582196 %, total balance 2878.460084,
# 81 [1.00000000e+00 0.00000000e+00 3.28515213e-17]
# 82 [0. 0. 1.]
# 83 [0. 0. 1.]
# 84 [0. 0. 1.]
# 85 [0. 0. 1.]
# 86 [1. 0. 0.]
# 87 [1. 0. 0.]
# 88 [0. 0. 1.]
# 89 [1. 0. 0.]
# 90 [1. 0. 0.]
# 91 [0. 1. 0.]
# day 91: buy 1 unit at price 1200.109985, total balance 1678.350099
# 92 [1. 0. 0.]
# 93 [0. 0. 1.]
# day 93, sell 1 unit at price 1168.189941, investment -2.659760 %, total balance 2846.540040,
# 94 [1. 0. 0.]
# 95 [0. 0. 1.]
# 96 [0. 1. 0.]
# day 96: buy 1 unit at price 1138.819946, total balance 1707.720094
# 97 [0. 0. 1.]
# day 97, sell 1 unit at price 1081.219971, investment -5.057865 %, total balance 2788.940065,
# 98 [0. 0. 1.]
# 99 [0. 0. 1.]
# 100 [0. 0. 1.]
# 101 [0. 0. 1.]
# 102 [0. 0. 1.]
# 103 [1. 0. 0.]
# 104 [0. 0. 1.]
# 105 [0. 0. 1.]
# 106 [1. 0. 0.]
# 107 [1.00000000e+000 0.00000000e+000 9.49243204e-193]
# 108 [0. 0. 1.]
# 109 [0. 0. 1.]
# 110 [0. 0. 1.]
# 111 [1. 0. 0.]
# 112 [0. 0. 1.]
# 113 [0. 0. 1.]
# 114 [0. 0. 1.]
# 115 [0. 0. 1.]
# 116 [1. 0. 0.]
# 117 [1. 0. 0.]
# 118 [1. 0. 0.]
# 119 [0. 0. 1.]
# 120 [1. 0. 0.]
# 121 [0. 0. 1.]
# 122 [0. 0. 1.]
# 123 [0. 0. 1.]
# 124 [1. 0. 0.]
# 125 [1. 0. 0.]
# 126 [0. 0. 1.]
# 127 [1. 0. 0.]
# 128 [1. 0. 0.]
# 129 [1. 0. 0.]
# 130 [1. 0. 0.]
# 131 [1. 0. 0.]
# 132 [1. 0. 0.]
# 133 [0. 0. 1.]
# 134 [1. 0. 0.]
# 135 [0. 0. 1.]
# 136 [0. 0. 1.]
# 137 [0. 0. 1.]
# 138 [0. 0. 1.]
# 139 [1.00000000e+000 0.00000000e+000 5.25615826e-287]
# 140 [0. 0. 1.]
# 141 [0. 0. 1.]
# 142 [0. 1. 0.]
# day 142: buy 1 unit at price 1042.099976, total balance 1746.840089
# 143 [0. 0. 1.]
# day 143, sell 1 unit at price 1016.530029, investment -2.453694 %, total balance 2763.370118,
# 144 [1.00000000e+000 0.00000000e+000 8.27532153e-309]
# 145 [1. 0. 0.]
# 146 [0. 0. 1.]
# 147 [0. 0. 1.]
# 148 [0. 0. 1.]
# 149 [0. 0. 1.]
# 150 [0. 0. 1.]
# 151 [0. 0. 1.]
# 152 [1. 0. 0.]
# 153 [0. 0. 1.]
# 154 [1. 0. 0.]
# 155 [1. 0. 0.]
# 156 [1. 0. 0.]
# 157 [1. 0. 0.]
# 158 [0. 0. 1.]
# 159 [0. 0. 1.]
# 160 [0. 0. 1.]
# 161 [0. 0. 1.]
# 162 [1. 0. 0.]
# 163 [1. 0. 0.]
# 164 [1. 0. 0.]
# 165 [1. 0. 0.]
# 166 [0. 1. 0.]
# day 166: buy 1 unit at price 1070.520020, total balance 1692.850098
# 167 [1. 0. 0.]
# 168 [1. 0. 0.]
# 169 [0. 0. 1.]
# day 169, sell 1 unit at price 1090.989990, investment 1.912152 %, total balance 2783.840088,
# 170 [0. 0. 1.]
# 171 [1. 0. 0.]
# 172 [0. 0. 1.]
# 173 [1. 0. 0.]
# 174 [1. 0. 0.]
# 175 [1. 0. 0.]
# 176 [0. 0. 1.]
# 177 [0. 0. 1.]
# 178 [1. 0. 0.]
# 179 [0. 0. 1.]
# 180 [0. 0. 1.]
# 181 [0. 0. 1.]
# 182 [0. 0. 1.]
# 183 [1. 0. 0.]
# 184 [0. 1. 0.]
# day 184: buy 1 unit at price 1113.650024, total balance 1670.190064
# 185 [0. 1. 0.]
# day 185: buy 1 unit at price 1118.560059, total balance 551.630005
# 186 [1. 0. 0.]
# 187 [0. 1. 0.]
# day 187: buy 1 unit at price 1096.969971, total balance -545.339966
# 188 [0. 0. 1.]
# day 188, sell 1 unit at price 1110.369995, investment -0.294530 %, total balance 565.030029,
# 189 [0. 0. 1.]
# day 189, sell 1 unit at price 1109.400024, investment -0.818913 %, total balance 1674.430053,
# 190 [0. 0. 1.]
# day 190, sell 1 unit at price 1115.130005, investment 1.655472 %, total balance 2789.560058,
# 191 [0. 0. 1.]
# 192 [1. 0. 0.]
# 193 [0. 0. 1.]
# 194 [1. 0. 0.]
# 195 [1. 0. 0.]
# 196 [0. 1. 0.]
# day 196: buy 1 unit at price 1157.859985, total balance 1631.700073
# 197 [1. 0. 0.]
# 198 [0. 0. 1.]
# day 198, sell 1 unit at price 1142.319946, investment -1.342135 %, total balance 2774.020019,
# 199 [0. 0. 1.]
# 200 [1. 0. 0.]
# 201 [0. 0. 1.]
# 202 [0. 0. 1.]
# 203 [0. 0. 1.]
# 204 [0. 0. 1.]
# 205 [0. 0. 1.]
# 206 [0. 0. 1.]
# 207 [0. 0. 1.]
# 208 [1. 0. 0.]
# 209 [0. 0. 1.]
# 210 [0. 0. 1.]
# 211 [1. 0. 0.]
# 212 [0. 0. 1.]
# 213 [0. 0. 1.]
# 214 [0. 0. 1.]
# 215 [0. 0. 1.]
# 216 [0. 0. 1.]
# 217 [0. 0. 1.]
# 218 [1. 0. 0.]
# 219 [1. 0. 0.]
# 220 [0. 0. 1.]
# 221 [1. 0. 0.]
# 222 [1. 0. 0.]
# 223 [1.00000000e+000 0.00000000e+000 7.17757702e-252]
# 224 [1. 0. 0.]
# 225 [1. 0. 0.]
# 226 [1. 0. 0.]
# 227 [1. 0. 0.]
# 228 [1. 0. 0.]
# 229 [1. 0. 0.]
# 230 [0. 0. 1.]
# 231 [0. 0. 1.]
# 232 [1. 0. 0.]
# 233 [0. 0. 1.]
# 234 [0. 0. 1.]
# 235 [0. 0. 1.]
# 236 [0. 1. 0.]
# 237 [0. 0. 1.]
# 238 [0. 0. 1.]
# 239 [0. 0. 1.]
# 240 [0. 0. 1.]
# 241 [0. 0. 1.]
# 242 [1. 0. 0.]
# 243 [0. 0. 1.]
# 244 [1. 0. 0.]
# 245 [0. 0. 1.]
# 246 [0. 0. 1.]
# 247 [0. 0. 1.]
# 248 [1. 0. 0.]
# 249 [0. 0. 1.]
# 250 [0. 0. 1.]

# %%
fig = plt.figure(figsize = (15, 5))
plt.plot(df['Close'], color='r', lw=2.)
plt.plot(df['Close'], '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(df['Close'], 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('GOOG total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()

# %%
df = pd.read_csv('TWTR.csv')
real_trend = df['Close'].tolist()
parameters = [df['Close'].tolist(), df['Volume'].tolist()]
minmax = MinMaxScaler(feature_range = (100, 200)).fit(np.array(parameters).T)
scaled_parameters = minmax.transform(np.array(parameters).T).T.tolist()
initial_money = np.max(parameters[0]) * 2

agent.change_data(timeseries = scaled_parameters,
                  skip = skip,
                  initial_money = initial_money,
                  real_trend = real_trend,
                  minmax = minmax)

states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# 0 [0. 0. 1.]
# 1 [0. 0. 1.]
# 2 [0. 0. 1.]
# 3 [0. 0. 1.]
# 4 [0. 0. 1.]
# 5 [0. 0. 1.]
# 6 [0. 0. 1.]
# 7 [0. 0. 1.]
# 8 [0. 0. 1.]
# 9 [0. 0. 1.]
# 10 [0. 0. 1.]
# 11 [0. 0. 1.]
# 12 [0. 0. 1.]
# 13 [0. 0. 1.]
# 14 [0. 0. 1.]
# 15 [0.00000000e+000 3.40479647e-175 1.00000000e+000]
# 16 [0. 1. 0.]
# day 16: buy 1 unit at price 45.799999, total balance 47.719997
# 17 [0. 1. 0.]
# day 17: buy 1 unit at price 46.000000, total balance 1.719997
# 18 [0. 1. 0.]
# 19 [0. 0. 1.]
# day 19, sell 1 unit at price 46.130001, investment 0.720528 %, total balance 47.849998,
# 20 [0. 0. 1.]
# day 20, sell 1 unit at price 45.240002, investment -1.652170 %, total balance 93.090000,
# 21 [0.00000000e+000 1.00000000e+000 2.67436731e-235]
# day 21: buy 1 unit at price 45.880001, total balance 47.209999
# 22 [0. 1. 0.]
# day 22: buy 1 unit at price 44.169998, total balance 3.040001
# 23 [0. 1. 0.]
# 24 [0. 0. 1.]
# day 24, sell 1 unit at price 43.700001, investment -4.751526 %, total balance 46.740002,
# 25 [0. 0. 1.]
# day 25, sell 1 unit at price 44.790001, investment 1.403675 %, total balance 91.530003,
# 26 [0. 0. 1.]
# 27 [0. 1. 0.]
# day 27: buy 1 unit at price 44.980000, total balance 46.550003
# 28 [0. 1. 0.]
# day 28: buy 1 unit at price 43.889999, total balance 2.660004
# 29 [0. 1. 0.]
# 30 [1. 0. 0.]
# 31 [0. 0. 1.]
# day 31, sell 1 unit at price 44.139999, investment -1.867499 %, total balance 46.800003,
# 32 [1. 0. 0.]
# 33 [1. 0. 0.]
# 34 [1. 0. 0.]
# 35 [0. 1. 0.]
# day 35: buy 1 unit at price 44.490002, total balance 2.310001
# 36 [1.00000000e+000 0.00000000e+000 5.82744325e-169]
# 37 [1. 0. 0.]
# 38 [0. 1. 0.]
# 39 [1. 0. 0.]
# 40 [0. 1. 0.]
# 41 [1. 0. 0.]
# 42 [0. 0. 1.]
# day 42, sell 1 unit at price 42.169998, investment -3.918890 %, total balance 44.479999,
# 43 [0. 1. 0.]
# day 43: buy 1 unit at price 44.220001, total balance 0.259998
# 44 [0. 0. 1.]
# day 44, sell 1 unit at price 42.939999, investment -3.483936 %, total balance 43.199997,
# 45 [0. 1. 0.]
# day 45: buy 1 unit at price 34.119999, total balance 9.079998
# 46 [0. 0. 1.]
# day 46, sell 1 unit at price 31.379999, investment -29.036639 %, total balance 40.459997,
# 47 [0. 0. 1.]
# day 47, sell 1 unit at price 31.870001, investment -6.594367 %, total balance 72.329998,
# 48 [0. 0. 1.]
# 49 [0. 0. 1.]
# 50 [0. 1. 0.]
# day 50: buy 1 unit at price 31.959999, total balance 40.369999
# 51 [0.00000000e+00 1.00000000e+00 6.31918131e-95]
# day 51: buy 1 unit at price 32.980000, total balance 7.389999
# 52 [1. 0. 0.]
# 53 [1. 0. 0.]
# 54 [1. 0. 0.]
# 55 [1. 0. 0.]
# 56 [1.00000000e+000 0.00000000e+000 3.17286162e-115]
# 57 [1. 0. 0.]
# 58 [0. 0. 1.]
# day 58, sell 1 unit at price 32.380001, investment 1.314149 %, total balance 39.770000,
# 59 [1. 0. 0.]
# 60 [0. 0. 1.]
# day 60, sell 1 unit at price 32.730000, investment -0.758035 %, total balance 72.500000,
# 61 [7.10285145e-314 0.00000000e+000 1.00000000e+000]
# 62 [0. 0. 1.]
# 63 [1. 0. 0.]
# 64 [1. 0. 0.]
# 65 [1. 0. 0.]
# 66 [0. 1. 0.]
# day 66: buy 1 unit at price 35.889999, total balance 36.610001
# 67 [1. 0. 0.]
# 68 [0. 1. 0.]
# day 68: buy 1 unit at price 35.349998, total balance 1.260003
# 69 [1. 0. 0.]
# 70 [0. 1. 0.]
# 71 [0.00000000e+000 1.00000000e+000 1.18732533e-304]
# 72 [0. 1. 0.]
# 73 [0. 0. 1.]
# day 73, sell 1 unit at price 30.809999, investment -14.154361 %, total balance 32.070002,
# 74 [0. 1. 0.]
# day 74: buy 1 unit at price 30.490000, total balance 1.580002
# 75 [0. 1. 0.]
# 76 [0. 1. 0.]
# 77 [0. 1. 0.]
# 78 [0. 1. 0.]
# 79 [0. 0. 1.]
# day 79, sell 1 unit at price 30.120001, investment -14.794900 %, total balance 31.700003,
# 80 [1. 0. 0.]
# 81 [0. 0. 1.]
# day 81, sell 1 unit at price 29.219999, investment -4.165303 %, total balance 60.920002,
# 82 [1. 0. 0.]
# 83 [1. 0. 0.]
# 84 [0. 0. 1.]
# 85 [1. 0. 0.]
# 86 [1. 0. 0.]
# 87 [1. 0. 0.]
# 88 [0. 0. 1.]
# 89 [0. 0. 1.]
# 90 [1. 0. 0.]
# 91 [1. 0. 0.]
# 92 [1. 0. 0.]
# 93 [0. 1. 0.]
# day 93: buy 1 unit at price 28.230000, total balance 32.690002
# 94 [1. 0. 0.]
# 95 [0. 0. 1.]
# day 95, sell 1 unit at price 28.450001, investment 0.779316 %, total balance 61.140003,
# 96 [0. 1. 0.]
# day 96: buy 1 unit at price 29.270000, total balance 31.870003
# 97 [0. 0. 1.]
# day 97, sell 1 unit at price 26.790001, investment -8.472836 %, total balance 58.660004,
# 98 [0. 0. 1.]
# 99 [1. 0. 0.]
# 100 [0. 0. 1.]
# 101 [0. 0. 1.]
# 102 [0. 0. 1.]
# 103 [0. 1. 0.]
# day 103: buy 1 unit at price 29.290001, total balance 29.370003
# 104 [1. 0. 0.]
# 105 [2.61943119e-54 0.00000000e+00 1.00000000e+00]
# day 105, sell 1 unit at price 29.180000, investment -0.375558 %, total balance 58.550003,
# 106 [0. 0. 1.]
# 107 [0. 0. 1.]
# 108 [0. 0. 1.]
# 109 [0. 0. 1.]
# 110 [0. 0. 1.]
# 111 [0. 0. 1.]
# 112 [0. 0. 1.]
# 113 [0. 0. 1.]
# 114 [0. 0. 1.]
# 115 [0. 0. 1.]
# 116 [0. 1. 0.]
# day 116: buy 1 unit at price 34.419998, total balance 24.130005
# 117 [0. 1. 0.]
# 118 [1. 0. 0.]
# 119 [0. 1. 0.]
# 120 [0. 1. 0.]
# 121 [0. 1. 0.]
# 122 [0. 1. 0.]
# 123 [0. 0. 1.]
# day 123, sell 1 unit at price 33.150002, investment -3.689704 %, total balance 57.280007,
# 124 [0. 0. 1.]
# 125 [0. 0. 1.]
# 126 [1. 0. 0.]
# 127 [1. 0. 0.]
# 128 [1. 0. 0.]
# 129 [1. 0. 0.]
# 130 [1. 0. 0.]
# 131 [1. 0. 0.]
# 132 [1. 0. 0.]
# 133 [3.00069994e-236 0.00000000e+000 1.00000000e+000]
# 134 [1. 0. 0.]
# 135 [1. 0. 0.]
# 136 [0. 0. 1.]
# 137 [0. 0. 1.]
# 138 [0. 0. 1.]
# 139 [0. 0. 1.]
# 140 [1. 0. 0.]
# 141 [0. 0. 1.]
# 142 [1. 0. 0.]
# 143 [0. 0. 1.]
# 144 [0. 0. 1.]
# 145 [0. 1. 0.]
# day 145: buy 1 unit at price 32.930000, total balance 24.350007
# 146 [0. 0. 1.]
# day 146, sell 1 unit at price 29.290001, investment -11.053747 %, total balance 53.640008,
# 147 [0. 0. 1.]
# 148 [0. 1. 0.]
# day 148: buy 1 unit at price 26.450001, total balance 27.190007
# 149 [0. 0. 1.]
# day 149, sell 1 unit at price 28.660000, investment 8.355383 %, total balance 55.850007,
# 150 [0. 1. 0.]
# day 150: buy 1 unit at price 28.680000, total balance 27.170007
# 151 [0. 1. 0.]
# day 151: buy 1 unit at price 28.430000, total balance -1.259993
# 152 [1. 0. 0.]
# 153 [0. 0. 1.]
# day 153, sell 1 unit at price 28.809999, investment 0.453274 %, total balance 27.550006,
# 154 [0. 0. 1.]
# day 154, sell 1 unit at price 27.990000, investment -1.547661 %, total balance 55.540006,
# 155 [1. 0. 0.]
# 156 [1. 0. 0.]
# 157 [1. 0. 0.]
# 158 [1. 0. 0.]
# 159 [1. 0. 0.]
# 160 [1. 0. 0.]
# 161 [1. 0. 0.]
# 162 [1. 0. 0.]
# 163 [0. 0. 1.]
# 164 [1. 0. 0.]
# 165 [1. 0. 0.]
# 166 [0. 1. 0.]
# day 166: buy 1 unit at price 32.250000, total balance 23.290006
# 167 [0. 1. 0.]
# 168 [0. 1. 0.]
# 169 [0. 1. 0.]
# 170 [0. 1. 0.]
# 171 [0. 1. 0.]
# 172 [0. 0. 1.]
# day 172, sell 1 unit at price 32.259998, investment 0.031002 %, total balance 55.550004,
# 173 [0. 1. 0.]
# day 173: buy 1 unit at price 33.560001, total balance 21.990003
# 174 [0. 0. 1.]
# day 174, sell 1 unit at price 33.189999, investment -1.102509 %, total balance 55.180002,
# 175 [1. 0. 0.]
# 176 [0. 0. 1.]
# 177 [1.00000000e+000 0.00000000e+000 3.09733285e-167]
# 178 [0. 1. 0.]
# day 178: buy 1 unit at price 30.799999, total balance 24.380003
# 179 [0. 0. 1.]
# day 179, sell 1 unit at price 30.010000, investment -2.564932 %, total balance 54.390003,
# 180 [0. 1. 0.]
# day 180: buy 1 unit at price 30.230000, total balance 24.160003
# 181 [0. 1. 0.]
# 182 [0. 0. 1.]
# day 182, sell 1 unit at price 31.120001, investment 2.944099 %, total balance 55.280004,
# 183 [0. 0. 1.]
# 184 [0. 0. 1.]
# 185 [0. 1. 0.]
# day 185: buy 1 unit at price 31.650000, total balance 23.630004
# 186 [1. 0. 0.]
# 187 [1. 0. 0.]
# 188 [1. 0. 0.]
# 189 [0. 0. 1.]
# day 189, sell 1 unit at price 31.990000, investment 1.074250 %, total balance 55.620004,
# 190 [0. 0. 1.]
# 191 [0. 0. 1.]
# 192 [1. 0. 0.]
# 193 [1. 0. 0.]
# 194 [0. 0. 1.]
# 195 [0. 0. 1.]
# 196 [1. 0. 0.]
# 197 [1. 0. 0.]
# 198 [1. 0. 0.]
# 199 [1. 0. 0.]
# 200 [1. 0. 0.]
# 201 [1. 0. 0.]
# 202 [1. 0. 0.]
# 203 [0.00000000e+00 1.00000000e+00 7.91513646e-16]
# day 203: buy 1 unit at price 31.219999, total balance 24.400005
# 204 [1. 0. 0.]
# 205 [1. 0. 0.]
# 206 [1.97563562e-256 0.00000000e+000 1.00000000e+000]
# day 206, sell 1 unit at price 32.570000, investment 4.324155 %, total balance 56.970005,
# 207 [1.00000000e+000 0.00000000e+000 4.44626312e-271]
# 208 [0. 0. 1.]
# 209 [1. 0. 0.]
# 210 [0. 1. 0.]
# day 210: buy 1 unit at price 33.060001, total balance 23.910004
# 211 [1. 0. 0.]
# 212 [0. 0. 1.]
# day 212, sell 1 unit at price 32.869999, investment -0.574719 %, total balance 56.780003,
# 213 [1. 0. 0.]
# 214 [0.0000e+000 1.0000e+000 3.1816e-319]
# day 214: buy 1 unit at price 33.439999, total balance 23.340004
# 215 [0. 1. 0.]
# 216 [0. 1. 0.]
# 217 [0. 1. 0.]
# 218 [0. 1. 0.]
# 219 [0.00000000e+000 1.00000000e+000 2.22781447e-273]
# 220 [0. 0. 1.]
# day 220, sell 1 unit at price 35.139999, investment 5.083732 %, total balance 58.480003,
# 221 [0. 0. 1.]
# 222 [1. 0. 0.]
# 223 [0. 0. 1.]
# 224 [0. 1. 0.]
# day 224: buy 1 unit at price 34.709999, total balance 23.770004
# 225 [0. 1. 0.]
# 226 [0. 1. 0.]
# 227 [0. 1. 0.]
# 228 [0. 1. 0.]
# 229 [0.00000000e+00 1.00000000e+00 4.12992047e-68]
# 230 [1. 0. 0.]
# 231 [1. 0. 0.]
# 232 [1.00000000e+00 7.01345533e-47 0.00000000e+00]
# 233 [0. 0. 1.]
# day 233, sell 1 unit at price 39.779999, investment 14.606742 %, total balance 63.550003,
# 234 [0. 0. 1.]
# 235 [0. 0. 1.]
# 236 [0. 1. 0.]
# 237 [4.92347934e-96 1.00000000e+00 0.00000000e+00]
# 238 [0. 1. 0.]
# 239 [1. 0. 0.]
# 240 [0. 1. 0.]
# 241 [0. 1. 0.]
# 242 [0. 0. 1.]
# 243 [0. 1. 0.]
# 244 [0. 0. 1.]
# 245 [0. 0. 1.]
# 246 [0. 0. 1.]
# 247 [1. 0. 0.]
# 248 [0. 1. 0.]
# 249 [1. 0. 0.]
# 250 [1. 0. 0.]

# %%
fig = plt.figure(figsize = (15, 5))
plt.plot(df['Close'], color='r', lw=2.)
plt.plot(df['Close'], '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(df['Close'], 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('TWTR total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()

# %%
from datetime import datetime

volume = df['Volume'].tolist()

for i in range(100):
    print(agent.trade([real_trend[i], volume[i]]))
# Out:
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.558061'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.558295'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.558430'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.558548'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.558661'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.558773'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.558884'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.558995'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.559104'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.559212'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.559320'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.559526'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.559662'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.559784'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.559900'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.560011'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.560121'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.560230'}
# {'status': 'data not enough to trade', 'action': 'fail', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.560339'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.561196'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 93.51999599999999, 'timestamp': '2020-11-13 18:05:47.562220'}
# [0.00000000e+000 1.00000000e+000 1.70775593e-216]
# {'status': 'buy 1 unit, cost 45.880001', 'action': 'buy', 'balance': 47.63999499999999, 'timestamp': '2020-11-13 18:05:47.563460'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 44.169998', 'action': 'buy', 'balance': 3.4699969999999922, 'timestamp': '2020-11-13 18:05:47.564295'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 3.4699969999999922, 'timestamp': '2020-11-13 18:05:47.565132'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 43.700001', 'investment': -4.751525615703452, 'gain': -2.1799999999999997, 'balance': 47.16999799999999, 'action': 'sell', 'timestamp': '2020-11-13 18:05:47.566078'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 44.790001', 'investment': 1.4036745032227622, 'gain': 0.6200030000000041, 'balance': 91.959999, 'action': 'sell', 'timestamp': '2020-11-13 18:05:47.567031'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 91.959999, 'timestamp': '2020-11-13 18:05:47.567741'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 44.980000', 'action': 'buy', 'balance': 46.979999, 'timestamp': '2020-11-13 18:05:47.568580'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 43.889999', 'action': 'buy', 'balance': 3.0900000000000034, 'timestamp': '2020-11-13 18:05:47.569266'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 3.0900000000000034, 'timestamp': '2020-11-13 18:05:47.570447'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 3.0900000000000034, 'timestamp': '2020-11-13 18:05:47.571178'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 44.139999', 'investment': -1.8674988883948442, 'gain': -0.8400010000000009, 'balance': 47.229999, 'action': 'sell', 'timestamp': '2020-11-13 18:05:47.572019'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 47.229999, 'timestamp': '2020-11-13 18:05:47.572511'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 47.229999, 'timestamp': '2020-11-13 18:05:47.573399'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 47.229999, 'timestamp': '2020-11-13 18:05:47.574090'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 44.490002', 'action': 'buy', 'balance': 2.7399969999999954, 'timestamp': '2020-11-13 18:05:47.574910'}
# [1.00000000e+000 0.00000000e+000 4.11279843e-161]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 2.7399969999999954, 'timestamp': '2020-11-13 18:05:47.575575'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 2.7399969999999954, 'timestamp': '2020-11-13 18:05:47.576334'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 2.7399969999999954, 'timestamp': '2020-11-13 18:05:47.577100'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 2.7399969999999954, 'timestamp': '2020-11-13 18:05:47.577921'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 2.7399969999999954, 'timestamp': '2020-11-13 18:05:47.578739'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 2.7399969999999954, 'timestamp': '2020-11-13 18:05:47.579715'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 42.169998', 'investment': -3.9188904971266836, 'gain': -1.7200009999999963, 'balance': 44.909994999999995, 'action': 'sell', 'timestamp': '2020-11-13 18:05:47.580522'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 44.220001', 'action': 'buy', 'balance': 0.6899939999999916, 'timestamp': '2020-11-13 18:05:47.581149'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 42.939999', 'investment': -3.4839355592746513, 'gain': -1.5500030000000038, 'balance': 43.62999299999999, 'action': 'sell', 'timestamp': '2020-11-13 18:05:47.582100'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 34.119999', 'action': 'buy', 'balance': 9.509993999999992, 'timestamp': '2020-11-13 18:05:47.583068'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 31.379999', 'investment': -29.036638872984206, 'gain': -12.840002000000005, 'balance': 40.88999299999999, 'action': 'sell', 'timestamp': '2020-11-13 18:05:47.583951'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 31.870001', 'investment': -6.594367133480859, 'gain': -2.249997999999998, 'balance': 72.75999399999999, 'action': 'sell', 'timestamp': '2020-11-13 18:05:47.584764'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 72.75999399999999, 'timestamp': '2020-11-13 18:05:47.585559'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 72.75999399999999, 'timestamp': '2020-11-13 18:05:47.586284'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 31.959999', 'action': 'buy', 'balance': 40.799994999999996, 'timestamp': '2020-11-13 18:05:47.587274'}
# [0.00000000e+00 1.00000000e+00 4.03520463e-76]
# {'status': 'buy 1 unit, cost 32.980000', 'action': 'buy', 'balance': 7.819994999999999, 'timestamp': '2020-11-13 18:05:47.587981'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 7.819994999999999, 'timestamp': '2020-11-13 18:05:47.588825'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 7.819994999999999, 'timestamp': '2020-11-13 18:05:47.589490'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 7.819994999999999, 'timestamp': '2020-11-13 18:05:47.590260'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 7.819994999999999, 'timestamp': '2020-11-13 18:05:47.590936'}
# [1.00000000e+000 0.00000000e+000 2.23929084e-107]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 7.819994999999999, 'timestamp': '2020-11-13 18:05:47.591890'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 7.819994999999999, 'timestamp': '2020-11-13 18:05:47.592619'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 32.380001', 'investment': 1.3141489772887671, 'gain': 0.4200020000000002, 'balance': 40.199996, 'action': 'sell', 'timestamp': '2020-11-13 18:05:47.593585'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 40.199996, 'timestamp': '2020-11-13 18:05:47.594379'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 32.730000', 'investment': -0.7580351728320195, 'gain': -0.25, 'balance': 72.92999599999999, 'action': 'sell', 'timestamp': '2020-11-13 18:05:47.595678'}
# [1.01e-321 0.00e+000 1.00e+000]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 72.92999599999999, 'timestamp': '2020-11-13 18:05:47.596374'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 72.92999599999999, 'timestamp': '2020-11-13 18:05:47.597274'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 72.92999599999999, 'timestamp': '2020-11-13 18:05:47.598125'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 72.92999599999999, 'timestamp': '2020-11-13 18:05:47.598941'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 72.92999599999999, 'timestamp': '2020-11-13 18:05:47.599687'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 35.889999', 'action': 'buy', 'balance': 37.03999699999999, 'timestamp': '2020-11-13 18:05:47.600433'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 37.03999699999999, 'timestamp': '2020-11-13 18:05:47.601162'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 35.349998', 'action': 'buy', 'balance': 1.6899989999999931, 'timestamp': '2020-11-13 18:05:47.601902'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 1.6899989999999931, 'timestamp': '2020-11-13 18:05:47.602680'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 1.6899989999999931, 'timestamp': '2020-11-13 18:05:47.603420'}
# [0.00000000e+000 1.00000000e+000 7.58183761e-286]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 1.6899989999999931, 'timestamp': '2020-11-13 18:05:47.604147'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 1.6899989999999931, 'timestamp': '2020-11-13 18:05:47.604921'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 30.809999', 'investment': -14.154360940494866, 'gain': -5.079999999999998, 'balance': 32.49999799999999, 'action': 'sell', 'timestamp': '2020-11-13 18:05:47.605667'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 30.490000', 'action': 'buy', 'balance': 2.0099979999999924, 'timestamp': '2020-11-13 18:05:47.606476'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 2.0099979999999924, 'timestamp': '2020-11-13 18:05:47.607178'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 2.0099979999999924, 'timestamp': '2020-11-13 18:05:47.608062'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 2.0099979999999924, 'timestamp': '2020-11-13 18:05:47.608707'}
# [0. 1. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 2.0099979999999924, 'timestamp': '2020-11-13 18:05:47.609568'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 30.120001', 'investment': -14.794900412724202, 'gain': -5.229996999999997, 'balance': 32.129999, 'action': 'sell', 'timestamp': '2020-11-13 18:05:47.610386'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 32.129999, 'timestamp': '2020-11-13 18:05:47.611149'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 29.219999', 'investment': -4.165303378156786, 'gain': -1.2700010000000042, 'balance': 61.349998, 'action': 'sell', 'timestamp': '2020-11-13 18:05:47.612234'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 61.349998, 'timestamp': '2020-11-13 18:05:47.613173'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 61.349998, 'timestamp': '2020-11-13 18:05:47.613989'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 61.349998, 'timestamp': '2020-11-13 18:05:47.614759'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 61.349998, 'timestamp': '2020-11-13 18:05:47.615729'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 61.349998, 'timestamp': '2020-11-13 18:05:47.616302'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 61.349998, 'timestamp': '2020-11-13 18:05:47.617183'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 61.349998, 'timestamp': '2020-11-13 18:05:47.617967'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 61.349998, 'timestamp': '2020-11-13 18:05:47.618805'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 61.349998, 'timestamp': '2020-11-13 18:05:47.619469'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 61.349998, 'timestamp': '2020-11-13 18:05:47.620254'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 61.349998, 'timestamp': '2020-11-13 18:05:47.621146'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 28.230000', 'action': 'buy', 'balance': 33.119997999999995, 'timestamp': '2020-11-13 18:05:47.622093'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 33.119997999999995, 'timestamp': '2020-11-13 18:05:47.622954'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 28.450001', 'investment': 0.7793163301452478, 'gain': 0.22000100000000344, 'balance': 61.569998999999996, 'action': 'sell', 'timestamp': '2020-11-13 18:05:47.624033'}
# [0. 1. 0.]
# {'status': 'buy 1 unit, cost 29.270000', 'action': 'buy', 'balance': 32.299999, 'timestamp': '2020-11-13 18:05:47.624658'}
# [0. 0. 1.]
# {'status': 'sell 1 unit, price 26.790001', 'investment': -8.47283566791937, 'gain': -2.4799989999999994, 'balance': 59.09, 'action': 'sell', 'timestamp': '2020-11-13 18:05:47.625735'}
# [0. 0. 1.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 59.09, 'timestamp': '2020-11-13 18:05:47.626396'}
# [1. 0. 0.]
# {'status': 'do nothing', 'action': 'nothing', 'balance': 59.09, 'timestamp': '2020-11-13 18:05:47.627271'}

# %%
import copy
import pickle

copy_model = copy.deepcopy(agent.model)

with open('model.pkl', 'wb') as fopen:
    pickle.dump(copy_model, fopen)
