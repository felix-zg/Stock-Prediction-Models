# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random

class Actor:
    def __init__(self, name, input_size, output_size, size_layer):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, input_size))
            feed_actor = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            self.logits = tf.layers.dense(feed_actor, output_size)

class Critic:
    def __init__(self, name, input_size, output_size, size_layer, learning_rate):
        with tf.variable_scope(name):
            self.X = tf.placeholder(tf.float32, (None, input_size))
            self.Y = tf.placeholder(tf.float32, (None, output_size))
            self.REWARD = tf.placeholder(tf.float32, (None, 1))
            feed_critic = tf.layers.dense(self.X, size_layer, activation = tf.nn.relu)
            feed_critic = tf.layers.dense(feed_critic, output_size, activation = tf.nn.relu) + self.Y
            feed_critic = tf.layers.dense(feed_critic, size_layer//2, activation = tf.nn.relu)
            self.logits = tf.layers.dense(feed_critic, 1)
            self.cost = tf.reduce_mean(tf.square(self.REWARD - self.logits))
            self.optimizer = tf.train.AdamOptimizer(learning_rate).minimize(self.cost)
            
class Agent:

    LEARNING_RATE = 0.001
    BATCH_SIZE = 32
    LAYER_SIZE = 256
    OUTPUT_SIZE = 3
    EPSILON = 0.5
    DECAY_RATE = 0.005
    MIN_EPSILON = 0.1
    GAMMA = 0.99
    MEMORIES = deque()
    MEMORY_SIZE = 300
    COPY = 1000
    T_COPY = 0

    def __init__(self, state_size, window_size, trend, skip):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        tf.reset_default_graph()
        self.actor = Actor('actor-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.actor_target = Actor('actor-target', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE)
        self.critic = Critic('critic-original', self.state_size, self.OUTPUT_SIZE, self.LAYER_SIZE, self.LEARNING_RATE)
        self.critic_target = Critic('critic-target', self.state_size, self.OUTPUT_SIZE, 
                                    self.LAYER_SIZE, self.LEARNING_RATE)
        self.grad_critic = tf.gradients(self.critic.logits, self.critic.Y)
        self.actor_critic_grad = tf.placeholder(tf.float32, [None, self.OUTPUT_SIZE])
        weights_actor = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.grad_actor = tf.gradients(self.actor.logits, weights_actor, -self.actor_critic_grad)
        grads = zip(self.grad_actor, weights_actor)
        self.optimizer = tf.train.AdamOptimizer(self.LEARNING_RATE).apply_gradients(grads)
        self.sess = tf.InteractiveSession()
        self.sess.run(tf.global_variables_initializer())
    
    def _assign(self, from_name, to_name):
        from_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=from_name)
        to_w = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope=to_name)
        for i in range(len(from_w)):
            assign_op = to_w[i].assign(from_w[i])
            self.sess.run(assign_op)
            
    def _memorize(self, state, action, reward, new_state, dead):
        self.MEMORIES.append((state, action, reward, new_state, dead))
        if len(self.MEMORIES) > self.MEMORY_SIZE:
            self.MEMORIES.popleft()
            
    def _select_action(self, state):
        if np.random.rand() < self.EPSILON:
            action = np.random.randint(self.OUTPUT_SIZE)
        else:
            prediction = self.sess.run(self.actor.logits, feed_dict={self.actor.X:[state]})[0]
            action = np.argmax(prediction)
        return action
    
    def _construct_memories_and_train(self, replay):
        states = np.array([a[0] for a in replay])
        new_states = np.array([a[3] for a in replay])
        Q = self.sess.run(self.actor.logits, feed_dict={self.actor.X: states})
        Q_target = self.sess.run(self.actor_target.logits, feed_dict={self.actor_target.X: states})
        grads = self.sess.run(self.grad_critic, feed_dict={self.critic.X:states, self.critic.Y:Q})[0]
        self.sess.run(self.optimizer, feed_dict={self.actor.X:states, self.actor_critic_grad:grads})
        
        rewards = np.array([a[2] for a in replay]).reshape((-1, 1))
        rewards_target = self.sess.run(self.critic_target.logits, 
                                       feed_dict={self.critic_target.X:new_states,self.critic_target.Y:Q_target})
        for i in range(len(replay)):
            if not replay[0][-1]:
                rewards[i] += self.GAMMA * rewards_target[i]
        cost, _ = self.sess.run([self.critic.cost, self.critic.optimizer], 
                                feed_dict={self.critic.X:states, self.critic.Y:Q, self.critic.REWARD:rewards})
        return cost
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array(res)
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self._select_action(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                if (self.T_COPY + 1) % self.COPY == 0:
                    self._assign('actor-original', 'actor-target')
                    self._assign('critic-original', 'critic-target')
                
                action = self._select_action(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                
                self._memorize(state, action, invest, next_state, starting_money < initial_money)
                state = next_state
                batch_size = min(len(self.MEMORIES), self.BATCH_SIZE)
                replay = random.sample(self.MEMORIES, batch_size)
                cost = self._construct_memories_and_train(replay)
                self.T_COPY += 1
                self.EPSILON = self.MIN_EPSILON + (1.0 - self.MIN_EPSILON) * np.exp(-self.DECAY_RATE * i)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# WARNING:tensorflow:From <ipython-input-3-d00a32b0a992>:8: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /Users/felixweizmann/Documents/GitHub/Stock-Prediction-Models/venv/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# epoch: 10, total rewards: 1226.204891.3, cost: 0.146983, total money: 6251.754878
# epoch: 20, total rewards: 1502.809748.3, cost: 14.326546, total money: 4582.559748
# epoch: 30, total rewards: -11.920040.3, cost: 1307420.000000, total money: 1490.469914
# epoch: 40, total rewards: 1308.230164.3, cost: 55167.882812, total money: 8306.030152
# epoch: 50, total rewards: 2517.344667.3, cost: 40640.179688, total money: 2901.254701
# epoch: 60, total rewards: 2158.900025.3, cost: 4700.870117, total money: 1719.749939
# epoch: 70, total rewards: 2151.299802.3, cost: 22572.845703, total money: 1613.279780
# epoch: 80, total rewards: 1733.380130.3, cost: 4295.310059, total money: 1232.350099
# epoch: 90, total rewards: 1940.220155.3, cost: 2141.628418, total money: 1621.870118
# epoch: 100, total rewards: 2199.610111.3, cost: 722.884399, total money: 870.670047
# epoch: 110, total rewards: 1432.895203.3, cost: 102.234222, total money: 6529.075196
# epoch: 120, total rewards: 1722.259828.3, cost: 1263.204102, total money: 338.709840
# epoch: 130, total rewards: 2073.715209.3, cost: 510.094299, total money: 2461.205258
# epoch: 140, total rewards: 1640.439700.3, cost: 5485.689941, total money: 1058.029665
# epoch: 150, total rewards: 847.914738.3, cost: 61397.277344, total money: 7819.354740
# epoch: 160, total rewards: 2433.059877.3, cost: 1415.750732, total money: 125.180054
# epoch: 170, total rewards: 2376.240052.3, cost: 773.635010, total money: 851.730040
# epoch: 180, total rewards: 2323.725155.3, cost: 17.477573, total money: 97.315183
# epoch: 190, total rewards: 2003.674925.3, cost: 9.170160, total money: 651.514892
# epoch: 200, total rewards: 2285.280149.3, cost: 35.138000, total money: 117.150144

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 0: buy 1 unit at price 768.700012, total balance 9231.299988
# day 1: buy 1 unit at price 762.130005, total balance 8469.169983
# day 2: buy 1 unit at price 762.020020, total balance 7707.149963
# day 3: buy 1 unit at price 782.520020, total balance 6924.629943
# day 4: buy 1 unit at price 790.510010, total balance 6134.119933
# day 7: buy 1 unit at price 754.020020, total balance 5380.099913
# day 8, sell 1 unit at price 736.080017, investment -4.243527 %, total balance 6116.179930,
# day 9: buy 1 unit at price 758.489990, total balance 5357.689940
# day 10: buy 1 unit at price 764.479980, total balance 4593.209960
# day 11: buy 1 unit at price 771.229980, total balance 3821.979980
# day 14, sell 1 unit at price 768.270020, investment 0.805639 %, total balance 4590.250000,
# day 15: buy 1 unit at price 760.989990, total balance 3829.260010
# day 16, sell 1 unit at price 761.679993, investment -0.044622 %, total balance 4590.940003,
# day 17: buy 1 unit at price 768.239990, total balance 3822.700013
# day 18: buy 1 unit at price 770.840027, total balance 3051.859986
# day 19: buy 1 unit at price 758.039978, total balance 2293.820008
# day 21: buy 1 unit at price 750.500000, total balance 1543.320008
# day 22: buy 1 unit at price 762.520020, total balance 780.799988
# day 23: buy 1 unit at price 759.109985, total balance 21.690003
# day 28, sell 1 unit at price 796.099976, investment 1.735413 %, total balance 817.789979,
# day 29: buy 1 unit at price 797.070007, total balance 20.719972
# day 30, sell 1 unit at price 797.849976, investment 0.928510 %, total balance 818.569948,
# day 31: buy 1 unit at price 790.799988, total balance 27.769960
# day 32, sell 1 unit at price 794.200012, investment 5.328770 %, total balance 821.969972,
# day 34: buy 1 unit at price 794.559998, total balance 27.409974
# day 47, sell 1 unit at price 807.909973, investment 6.515575 %, total balance 835.319947,
# day 48: buy 1 unit at price 806.359985, total balance 28.959962
# day 57, sell 1 unit at price 832.150024, investment 8.851775 %, total balance 861.109986,
# day 60: buy 1 unit at price 796.789978, total balance 64.320008
# day 68, sell 1 unit at price 813.669983, investment 5.502898 %, total balance 877.989991,
# day 69: buy 1 unit at price 819.239990, total balance 58.750001
# day 71, sell 1 unit at price 818.979980, investment 7.620335 %, total balance 877.729981,
# day 72: buy 1 unit at price 824.159973, total balance 53.570008
# day 73, sell 1 unit at price 828.070007, investment 7.787933 %, total balance 881.640015,
# day 74: buy 1 unit at price 831.659973, total balance 49.980042
# day 76, sell 1 unit at price 831.330017, investment 7.847282 %, total balance 881.310059,
# day 77: buy 1 unit at price 828.640015, total balance 52.670044
# day 84, sell 1 unit at price 831.909973, investment 9.744868 %, total balance 884.580017,
# day 85: buy 1 unit at price 835.369995, total balance 49.210022
# day 95, sell 1 unit at price 829.590027, investment 10.538311 %, total balance 878.800049,
# day 96: buy 1 unit at price 817.580017, total balance 61.220032
# day 98, sell 1 unit at price 819.510010, investment 7.473901 %, total balance 880.730042,
# day 99: buy 1 unit at price 820.919983, total balance 59.810059
# day 102, sell 1 unit at price 829.559998, investment 9.280607 %, total balance 889.370057,
# day 103: buy 1 unit at price 838.549988, total balance 50.820069
# day 112, sell 1 unit at price 837.169983, investment 5.030923 %, total balance 887.990052,
# day 113, sell 1 unit at price 836.820007, investment 5.819426 %, total balance 1724.810059,
# day 114: buy 1 unit at price 838.210022, total balance 886.600037
# day 115, sell 1 unit at price 841.650024, investment 5.926554 %, total balance 1728.250061,
# day 116: buy 1 unit at price 843.190002, total balance 885.060059
# day 117: buy 1 unit at price 862.760010, total balance 22.300049
# day 128, sell 1 unit at price 932.169983, investment 15.602212 %, total balance 954.470032,
# day 129: buy 1 unit at price 928.780029, total balance 25.690003
# day 131, sell 1 unit at price 932.219971, investment 16.996950 %, total balance 957.909974,
# day 132, sell 1 unit at price 937.080017, investment 14.384067 %, total balance 1894.989991,
# day 133: buy 1 unit at price 943.000000, total balance 951.989991
# day 134: buy 1 unit at price 919.619995, total balance 32.369996
# day 136, sell 1 unit at price 934.010010, investment 13.328728 %, total balance 966.380006,
# day 137: buy 1 unit at price 941.859985, total balance 24.520021
# day 142, sell 1 unit at price 975.880005, investment 17.341226 %, total balance 1000.400026,
# day 143: buy 1 unit at price 964.859985, total balance 35.540041
# day 144, sell 1 unit at price 966.950012, investment 16.691204 %, total balance 1002.490053,
# day 145: buy 1 unit at price 975.599976, total balance 26.890077
# day 153, sell 1 unit at price 950.760010, investment 13.813043 %, total balance 977.650087,
# day 155: buy 1 unit at price 939.780029, total balance 37.870058
# day 177, sell 1 unit at price 970.890015, investment 18.751681 %, total balance 1008.760073,
# day 178: buy 1 unit at price 968.150024, total balance 40.610049
# day 183, sell 1 unit at price 934.090027, investment 13.785758 %, total balance 974.700076,
# day 184: buy 1 unit at price 941.530029, total balance 33.170047
# day 187, sell 1 unit at price 930.390015, investment 10.952242 %, total balance 963.560062,
# day 189, sell 1 unit at price 927.960022, investment 10.707340 %, total balance 1891.520084,
# day 192: buy 1 unit at price 922.900024, total balance 968.620060
# day 193: buy 1 unit at price 907.239990, total balance 61.380070
# day 206, sell 1 unit at price 921.289978, investment 9.262441 %, total balance 982.670048,
# day 207: buy 1 unit at price 929.570007, total balance 53.100041
# day 209, sell 1 unit at price 937.340027, investment 8.644353 %, total balance 990.440068,
# day 210: buy 1 unit at price 928.450012, total balance 61.990056
# day 212, sell 1 unit at price 935.950012, investment 0.771979 %, total balance 997.940068,
# day 213, sell 1 unit at price 926.500000, investment -1.749735 %, total balance 1924.440068,
# day 214: buy 1 unit at price 929.080017, total balance 995.360051
# day 215: buy 1 unit at price 932.070007, total balance 63.290044
# day 218, sell 1 unit at price 920.289978, investment 0.072854 %, total balance 983.580022,
# day 219: buy 1 unit at price 915.000000, total balance 68.580022
# day 222, sell 1 unit at price 932.450012, investment -0.999084 %, total balance 1001.030034,
# day 223: buy 1 unit at price 928.530029, total balance 72.500005
# day 224, sell 1 unit at price 920.969971, investment -4.548848 %, total balance 993.469976,
# day 225: buy 1 unit at price 924.859985, total balance 68.609991
# day 230, sell 1 unit at price 957.789978, investment -1.825543 %, total balance 1026.399969,
# day 231: buy 1 unit at price 951.679993, total balance 74.719976
# day 233, sell 1 unit at price 978.890015, investment 4.161611 %, total balance 1053.609991,
# day 234: buy 1 unit at price 977.000000, total balance 76.609991
# day 240, sell 1 unit at price 992.179993, investment 2.482050 %, total balance 1068.789984,
# day 241: buy 1 unit at price 992.809998, total balance 75.979986
# day 246, sell 1 unit at price 973.330017, investment 3.377480 %, total balance 1049.310003,
# day 247: buy 1 unit at price 972.559998, total balance 76.750005

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
